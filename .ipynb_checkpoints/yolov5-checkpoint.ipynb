# %%
# %cd yolov5
# Out:
# C:\Users\Vali\Desktop\yolov5\yolov5

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117
# Out:
# ^C

# %%
# install dependencies as necessary
# !pip uninstall torch -y
# !pip install -qr requirements.txt
# Out:
# WARNING: Ignoring invalid distribution ~orch (C:\Users\Vali\anaconda3\Lib\site-packages)
# WARNING: Skipping torch as it is not installed.
# WARNING: Ignoring invalid distribution ~orch (C:\Users\Vali\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Users\Vali\anaconda3\Lib\site-packages)

# %%
import torch

from IPython.display import Image, clear_output  # to display images
from utils.downloads import attempt_download  # to download models/datasets

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 2.0.1+cpu CPU

# %%
# %cat dataset/data.yaml
# Out:
# UsageError: Line magic function `%cat` not found.

# %%
import yaml
import os
with open(os.getcwd() + "/../data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])

# %%
# %cat models/yolov5s.yaml
# Out:
# UsageError: Line magic function `%cat` not found.

# %%
#customize iPython writefile so we can write variables
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# %%writetemplate models/custom_yolov5s.yaml
#
# # parameters
# nc: {num_classes}  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Focus, [64, 3]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 9, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, BottleneckCSP, [1024, False]],  # 9
#   ]
#
# # YOLOv5 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, BottleneckCSP, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, BottleneckCSP, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, BottleneckCSP, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %%
torch.cuda.is_available()
# Out:
# False

# %%
# train yolov5s on custom data for 100 epochs
# time its performance
#%%time
# !python train.py --img 416 --batch 16 --epochs 10 --data ../data.yaml --cfg ./models/custom_yolov5s.yaml --weights '' --name yolov5s_results  --cache
# Out:
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# Local version label can only be used with `==` or `!=` operators
#     torch>=1.7.0+cuda
#          ~~~~~~~^
# train: weights='', cfg=./models/custom_yolov5s.yaml, data=../data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=10, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5  2023-9-11 Python-3.11.4 torch-2.0.1+cpu CPU
#
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs
# Out:
#       <iframe id="tensorboard-frame-2189e184b0a68395" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-2189e184b0a68395");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
from utils.plots import plot_results  # plot results.txt as results.png
Image(filename='./runs/train/yolov5s_results10/results.png', width=1000)  # view results.png

# %%
print("GROUND TRUTH AUGMENTED TRAINING DATA:")
Image(filename='./runs/train/yolov5s_results10/train_batch0.jpg', width=900)
# Out:
# GROUND TRUTH AUGMENTED TRAINING DATA:

# %%
# !python detect.py --weights ./runs/train/yolov5s_results10/weights/best.pt --img 416 --conf 0.4 --source ../test/images
# Out:
# Local version label can only be used with `==` or `!=` operators
#     torch>=1.7.0+cuda
#          ~~~~~~~^
# detect: weights=['./runs/train/yolov5s_results10/weights/best.pt'], source=../test/images, data=data\coco128.yaml, imgsz=[416, 416], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  2023-9-11 Python-3.11.4 torch-2.0.1+cpu CPU
#
# Fusing layers...
# custom_YOLOv5s summary: 232 layers, 7246518 parameters, 0 gradients, 16.7 GFLOPs
# image 1/207 C:\Users\Vali\Desktop\yolov5\test\images\00001285_jpg.rf.8e07b2a1a6dc7907bc68ee701ff32650.jpg: 416x416 Done. (0.078s)
# ...
